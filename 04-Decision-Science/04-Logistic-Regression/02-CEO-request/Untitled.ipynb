# %% [markdown]
# ## Problem tatement

# %% [markdown]
# Should Olist remove underperforming sellers from its marketplace?

# %% [markdown]
# ## Answer

# %% [markdown]
# data:image/png;base64,...![image.png](attachment:image.png)

# %% [markdown]
# ## Analyse

# %% [markdown]
# ## Perspectives

# %% [markdown]
# + Influence of seuil on profite
# + Influence of distance to customer on profite
